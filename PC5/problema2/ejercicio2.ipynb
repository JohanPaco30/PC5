# %%
import pandas as pd
df_vinos = pd.read_csv("winemag-data-130k-v2.csv")

# %%
df_vinos.head()

# %% [markdown]
# RENOMBRANDO EL TITULO DE LOS ENCABEZADOS:

# %%
df_rename = df_vinos.rename(columns= {'country':'país', 'points':'puntos', 'price':'precio','province':'provincia', 'winery':'bodega', 'variety':'tipo_vino', 'taster_name':'nombre_catador'})
df_drop = df_rename.drop(['Unnamed: 0'], axis = 1)
df_drop.head(10)

# %% [markdown]
# AGREGANDO COLUMNAS:

# %%
def nota_precio(precio:float):

    if precio > 0 and precio <=500:
        return 'Barato'
    elif precio > 500 and precio <=1000:
        return 'Normal'
    elif precio > 1000 and precio <=1500:
        return 'Caro'
    elif precio > 1500 and precio <=2500:
        return 'Muy Caro'
    else:
        return 'Sin apreciación'

df_drop['Apreciación_Precio'] = df_drop.precio.apply(nota_precio)
df_drop.head(5)

# %%
def nota_precio(puntos:int):

    if puntos >= 80 and puntos <=90:
        return 'Muy Bueno'
    elif puntos > 90 and puntos <=95:
        return 'Atractivo'
    elif puntos > 95 and puntos <=100:
        return 'Excepcional'
    else:
        return 'Sin apreciación'

df_drop['Apreciación_Calidad'] = df_drop.puntos.apply(nota_precio)
df_drop.head(5)

# %%
df_fil = df_drop.sort_values(by = ['precio'], ascending= False)
df_fil.head(5)

# %%
# COLUMNA FILTRADA PARA AQUELLOS QUE DESEAN UN SOLO VINO EXCEPCIONAL Y LES IMPORTA EL PRECIO
df_fil['CRITICA'] = 'NO RECOMENDABLE'

df_fil.loc[(df_fil['Apreciación_Precio'] == 'Barato') & (df_fil['Apreciación_Calidad'] == 'Excepcional'), 'CRITICA'] = 'Calidad/Precio'
df_fil.loc[(df_fil['Apreciación_Precio'] == 'Normal') & (df_fil['Apreciación_Calidad'] == 'Excepcional'), 'CRITICA'] = 'Moderado'
df_fil.loc[(df_fil['Apreciación_Precio'] == 'Caro') & (df_fil['Apreciación_Calidad'] == 'Excepcional'), 'CRITICA'] = 'Hay mejores'
df_fil.loc[(df_fil['Apreciación_Precio'] == 'Muy Caro') & (df_fil['Apreciación_Calidad'] == 'Excepcional'), 'CRITICA'] = 'No lo Vale'
df_fil.loc[(df_fil['Apreciación_Precio'] == 'Sin apreciación') & (df_fil['Apreciación_Calidad'] == 'Excepcional'), 'CRITICA'] = 'Sin Apreciación'



df_fil.head(5)
# Out:
#          país                                        description designation  \
# 15840  France  The wine is a velvet glove in an iron fist. Th...         NaN
# 65352  France  This extravagantly perfumed wine has great jui...         NaN
# 1558   France  A massive wine for Margaux, packed with tannin...         NaN
# 1575   France  The purest Cabernet Sauvignon fruit, with dark...         NaN
# 1571   France  Solid, very structured, packed with dense and ...         NaN
#
#        puntos  precio provincia        region_1 region_2 nombre_catador  \
# 15840      96  2500.0  Bordeaux         Pomerol      NaN     Roger Voss
# 65352      97  2000.0  Bordeaux         Pomerol      NaN     Roger Voss
# 1558       98  1900.0  Bordeaux         Margaux      NaN     Roger Voss
# 1575       96  1300.0  Bordeaux        Pauillac      NaN     Roger Voss
# 1571       96  1200.0  Bordeaux  Pessac-Léognan      NaN     Roger Voss
#
#       taster_twitter_handle                                     title  \
# 15840            @vossroger              Château Pétrus 2014  Pomerol
# 65352            @vossroger              Château Pétrus 2011  Pomerol
# 1558             @vossroger             Château Margaux 2009  Margaux
# 1575             @vossroger  Château Mouton Rothschild 2009  Pauillac
# 1571             @vossroger   Château Haut-Brion 2009  Pessac-Léognan
#
#                       tipo_vino                     bodega Apreciación_Precio  \
# 15840  Bordeaux-style Red Blend             Château Pétrus           Muy Caro
# 65352  Bordeaux-style Red Blend             Château Pétrus           Muy Caro
# 1558   Bordeaux-style Red Blend            Château Margaux           Muy Caro
# 1575   Bordeaux-style Red Blend  Château Mouton Rothschild               Caro
# 1571   Bordeaux-style Red Blend         Château Haut-Brion               Caro
#
#       Apreciación_Calidad      CRITICA
# 15840         Excepcional   No lo Vale
# 65352         Excepcional   No lo Vale
# 1558          Excepcional   No lo Vale
# 1575          Excepcional  Hay mejores
# 1571          Excepcional  Hay mejores

# %% [markdown]
# GENERANDO REPORTES:

# %%
#EL CATADOR DE LOS VINOS, MOSTRANDO DETALLES EXTRAS
df_catador = df_fil[['nombre_catador','title','description','puntos']].sort_values('nombre_catador', ascending= True)
df_catador.head(5)
# Out:
#            nombre_catador                                              title  \
# 55121  Alexander Peartree     Verterra 2014 Pinot Blanc (Leelanau Peninsula)
# 43604  Alexander Peartree  Los Pinos Ranch 2015 Texican Red (Texas High P...
# 55293  Alexander Peartree       Brennan 2012 Super Nero Nero d'Avola (Texas)
# 37950  Alexander Peartree                 Nevada Ridge 2011 Barbera (Nevada)
# 7934   Alexander Peartree  Canyon Wind 2012 Clone 4 Cabernet Sauvignon (G...
#
#                                              description  puntos
# 55121  Estery aromas of pear and apple mark the nose....      85
# 43604  Soft, approachable and easily structured, this...      84
# 55293  Bing cherry meets soft vanilla and coffee tone...      86
# 37950  There are lots of dried tones to the nose: her...      85
# 7934   Concentrated black and red berries show depth ...      90

# %%
#LA CALIDAD DE LOS VINOS CATADOS, MOSTRANDO LOS PUNTOS OBTENIDOS Y SU APRECIACIÓN
df_tipo = df_fil[['tipo_vino','description','puntos','Apreciación_Calidad']].sort_values('tipo_vino', ascending= True)
df_tipo.head(5)
# Out:
#          tipo_vino                                        description  puntos  \
# 45401     Abouriou  Comprised 100% of this rare variety, this wine...      85
# 51714  Agiorgitiko  Cedar, violet and red forest fruit aromas star...      92
# 53376  Agiorgitiko  This red starts with black fruits and pepper a...      88
# 15708  Agiorgitiko  Notes of cola, black pepper and cocoa on the n...      88
# 33129  Agiorgitiko  Plum, spice and red berries on the nose and pa...      85
#
#       Apreciación_Calidad
# 45401           Muy Bueno
# 51714           Atractivo
# 53376           Muy Bueno
# 15708           Muy Bueno
# 33129           Muy Bueno

# %%
#EL PRECIO DE LOS VINOS CATADOS, MOSTRANDO SU VALOR Y SU APRECIACIÓN
df_tipo2 = df_fil[['tipo_vino','description','precio','Apreciación_Precio']].sort_values('tipo_vino', ascending= True)
df_tipo2.head(5)
# Out:
#          tipo_vino                                        description  precio  \
# 45401     Abouriou  Comprised 100% of this rare variety, this wine...    75.0
# 51714  Agiorgitiko  Cedar, violet and red forest fruit aromas star...    19.0
# 53376  Agiorgitiko  This red starts with black fruits and pepper a...    45.0
# 15708  Agiorgitiko  Notes of cola, black pepper and cocoa on the n...    45.0
# 33129  Agiorgitiko  Plum, spice and red berries on the nose and pa...    13.0
#
#       Apreciación_Precio
# 45401             Barato
# 51714             Barato
# 53376             Barato
# 15708             Barato
# 33129             Barato

# %%
df_filtro = df_fil[['tipo_vino','description','puntos','precio','Apreciación_Precio','Apreciación_Calidad','CRITICA']].sort_values('tipo_vino', ascending= True)
df_excepcional = df_filtro['Apreciación_Calidad'] == 'Excepcional'
df_final = df_filtro[df_excepcional]
df_final
# Out:
#                       tipo_vino  \
# 54299                 Aglianico
# 9899         Alsace white blend
# 55724  Bordeaux-style Red Blend
# 15841  Bordeaux-style Red Blend
# 54303  Bordeaux-style Red Blend
# ...                         ...
# 45988               White Blend
# 33840               White Blend
# 46002               White Blend
# 31402                 Zinfandel
# 4504                  Zinfandel
#
#                                              description  puntos  precio  \
# 54299  Mature dark-skinned berry, leather, underbrush...      97    90.0
# 9899   Deliciously heady notes of peach and chamomile...      96    78.0
# 55724  Hard to exaggerate the beauty of this mountain...      96    75.0
# 15841  This is a powerful wine, made to age for a lon...      96    75.0
# 54303  This is an impressive wine that transcends the...      96    65.0
# ...                                                  ...     ...     ...
# 45988  This ethereal Tokaji Aszú is golden in color, ...      97    80.0
# 33840  A true labor of love, this fabulous Vin Santo ...      97     NaN
# 46002  Straw colored with gold reflections, this deli...      96    54.0
# 31402  A perennial knockout, this vintage delivers as...      96    58.0
# 4504   This wine is insanely good, from a dry-farmed,...      97    50.0
#
#       Apreciación_Precio Apreciación_Calidad          CRITICA
# 54299             Barato         Excepcional   Calidad/Precio
# 9899              Barato         Excepcional   Calidad/Precio
# 55724             Barato         Excepcional   Calidad/Precio
# 15841             Barato         Excepcional   Calidad/Precio
# 54303             Barato         Excepcional   Calidad/Precio
# ...                  ...                 ...              ...
# 45988             Barato         Excepcional   Calidad/Precio
# 33840    Sin apreciación         Excepcional  Sin Apreciación
# 46002             Barato         Excepcional   Calidad/Precio
# 31402             Barato         Excepcional   Calidad/Precio
# 4504              Barato         Excepcional   Calidad/Precio
#
# [423 rows x 7 columns]

# %% [markdown]
# EXPORTANDO TABLA FINAL:

# %%
df_final.to_excel('CRITICA_VINOS.xlsx', sheet_name= 'VINO_EXCEPCIONAL',index= False ,engine= 'openpyxl')
